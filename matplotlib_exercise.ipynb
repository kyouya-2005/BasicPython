# %% [markdown]
# # 【確認課題】Matplotlib

# %%
# 使うライブラリ
# !pip install japanize-matplotlib

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import japanize_matplotlib
japanize_matplotlib.japanize()

# %% [markdown]
# ## 1問目
# 使うcsvはhist_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問1](./imgs/matplotlib/plot_1.png)

# %%
df = pd.read_csv('data/hist_data.csv')
plt.hist(df['bデータ'], bins = 30)
plt.hist(df['aデータ'], bins = 30)
plt.xlabel('温度(℃)')
plt.ylabel('度数')
plt.title('aデータとbデータの温度に関する度数分布')
# Out:
# Text(0.5, 1.0, 'aデータとbデータの温度に関する度数分布')

# %% [markdown]
# ## 2問目
# 使うcsvはscatter_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問2](./imgs/matplotlib/plot_2.png)

# %%
df = pd.read_csv('data/scatter_data.csv')
plt.scatter(df['length (cm)'], df['width (cm)'], c=df['class'])
plt.xlabel('length (cm)')
plt.ylabel('width (cm)')
plt.title('クラス0～2のlengthとwidthに関する散布図')
plt.grid(True)

# %% [markdown]
# ## 3問目
# 使うcsvはline_data.csvです。下に2つの画像を表示するコードを書いてください。

# %% [markdown]
# ![問3_1](./imgs/matplotlib/plot_3_1.png)

# %% [markdown]
# ![問3_2](./imgs/matplotlib/plot_3_2.png)

# %%
df = pd.read_csv('data/line_data.csv')
plt.plot(df['期間'], df['件数'], marker='o', markersize=5, linestyle='-')
plt.xlabel('期間')
plt.ylabel('件数')
plt.title('期間ごとの件数の推移')
plt.grid(True)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, '2016下半期'),
#   Text(1, 0, '2017上半期'),
#   Text(2, 0, '2017下半期'),
#   Text(3, 0, '2018上半期'),
#   Text(4, 0, '2018下半期'),
#   Text(5, 0, '201上半期'),
#   Text(6, 0, '2019下半期'),
#   Text(7, 0, '2020上半期')])

# %%
df = pd.read_csv('data/line_data.csv')
plt.bar(df['期間'], df['費用'])
plt.xlabel('期間')
plt.ylabel('費用（円）')
plt.title('期間ごとの費用の推移')
plt.grid(True)
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, '2016下半期'),
#   Text(1, 0, '2017上半期'),
#   Text(2, 0, '2017下半期'),
#   Text(3, 0, '2018上半期'),
#   Text(4, 0, '2018下半期'),
#   Text(5, 0, '201上半期'),
#   Text(6, 0, '2019下半期'),
#   Text(7, 0, '2020上半期')])
